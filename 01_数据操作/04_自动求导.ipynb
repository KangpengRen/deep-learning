# %%
import torch

# %%
x = torch.arange(4, dtype=torch.float32)
x
# Out:
# tensor([0., 1., 2., 3.])

# %%
x.requires_grad_(True)  # 等价于 x = torch.arange(4, dtype=torch.float32, requires_grad=True)
x.grad

# %%
# 计算y
y = 2 * torch.dot(x, x)
y
# Out:
# tensor(28., grad_fn=<MulBackward0>)

# %%
# 通过调用反向传播函数自动计算y关于x每个分量的梯度
y.backward()
x.grad
# Out:
# tensor([ 0.,  4.,  8., 12.])

# %%
x.grad == 4 * x
# Out:
# tensor([True, True, True, True])

# %%
# 在默认情况下，PyTorch会累积梯度，偶们需要清除之前的值
x.grad.zero_()
y = x.sum()
y.backward()
x.grad
# Out:
# tensor([1., 1., 1., 1.])

# %%
x.grad.zero_()
y = x * x
# 等价与 y.backward(torch.ones(len(x)))
y.sum().backward()
x.grad
# Out:
# tensor([0., 2., 4., 6.])

# %%
x.grad.zero_()
y = x * x
u = y.detach()  # 将某些计算移动到记录的计算图之外
z = u * x

z.sum().backward()
x.grad == u
# Out:
# tensor([True, True, True, True])

# %%
# 即使构建函数的计算图需要通过Python控制流，我们仍然可以计算得到变量的梯度
def f(a):
    b = a * 2
    while b.norm() < 1000:
        b = b * 2
    if b.sum() > 0:
        c = b
    else:
        c = 100 * b
    return c


a = torch.randn(size=(), requires_grad=True)
d = f(a)
d.backward()

a.grad == d / a
# Out:
# tensor(True)
